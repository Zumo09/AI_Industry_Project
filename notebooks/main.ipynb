# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils.data as data

dataset = data.read_dataset()
# Out:
#   0%|          | 0/249 [00:00<?, ?it/s]

# %%
dataset[0]
# Out:
#                 timestamp  avg:ambient  var:ambient  max:ambient  min:ambient  \
# index
# 24    2020-06-01 00:00:00    25.575000     0.005000         25.6         25.4
# 27    2020-06-01 00:15:00    25.560000     0.006857         25.6         25.4
# 30    2020-06-01 00:30:00    25.600000     0.000000         25.6         25.6
# 33    2020-06-01 00:45:00    25.600000     0.000000         25.6         25.6
# 36    2020-06-01 01:00:00    25.571429     0.005275         25.6         25.4
# ...                   ...          ...          ...          ...          ...
# 96177 2021-04-30 20:45:00    24.533333     0.009524         24.6         24.4
# 96180 2021-04-30 21:00:00    24.600000     0.000000         24.6         24.6
# 96183 2021-04-30 21:15:00    24.600000     0.000000         24.6         24.6
# 96186 2021-04-30 21:30:00    24.560000     0.006857         24.6         24.4
# 96192 2021-04-30 22:00:00    24.800000     0.000000         24.8         24.8
#
# ...
